# %% [markdown]
# <a href="https://colab.research.google.com/github/Monykaramos/Monykaramos/blob/main/exercicios_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))

if idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")
# Out:
# Digite sua idade: 18
# Menor de idade

# %%
numero = int(input("Digite um número: "))

if numero % 2 == 0:
    print("Par")
else:
    print("Ímpar")
# Out:
# Digite um número: 2
# Par

# %%
valor_compra = float(input("Digite o valor da compra: "))
cliente_vip = input("Cliente VIP? (s/n): ")

desconto = 0

if valor_compra > 100:
    desconto = 10

if valor_compra > 200:
    desconto = 20

if cliente_vip == "s":
    desconto = desconto + 5

valor_final = valor_compra - (desconto/100 * valor_compra)

print("Desconto aplicado:", desconto, "%")
print("Valor final:", valor_final)
# Out:
# Digite o valor da compra: 110
# Cliente VIP? (s/n): s
# Desconto aplicado: 15 %
# Valor final: 93.5

# %%
usuario_correto = "admin"
senha_correta = "1234"

usuario = input("Usuário: ")
senha = input("Senha: ")

if usuario == usuario_correto:
    print("Usuário correto")
else:
    print("Usuário incorreto")

if senha == senha_correta:
    print("Login realizado")
else:
    print("Senha incorreta")
# Out:
# Usuário: kdfksjdf
# Senha: 1234
# Usuário incorreto
# Login realizado

# %%
usuario_correto = "admin"
senha_correta = "1234"

usuario = input("Usuário: ")

if usuario == usuario_correto:
    print("Usuário correto")
    senha = input("Senha: ")
    if senha == senha_correta:
      print("Login realizado")
    else:
      print("Senha incorreta")
else:
    print("Usuário incorreto")
# Out:
# Usuário: dfasf
# Usuário incorreto

# %%
quantidade = int(input("Quantos números deseja digitar? "))

maior = 0
menor = 0

for i in range(quantidade):
    numero = int(input("Digite um número: "))

    if numero > maior:
        maior = numero

    if numero < maior:
        menor = numero

print("Maior valor:", maior)
print("Menor valor:", menor)
# Out:
# Quantos números deseja digitar? 3
# Digite um número: 2
# Digite um número: 5
# Digite um número: 0
# Maior valor: 5
# Menor valor: 0
